# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshamsharma57/US-Home-Prices-Influencing-Factors/blob/main/Saksham_UShomeprice(PT_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **DATA PREPARATION**

# %% [markdown]
# **Importing libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Performing ***Extract Transform Load (ETL)***
#
# Data for all the variables is downloaded, preprocessed, and combined to create a dataset

# %%
df_cs = pd.read_csv('/content/CSUSHPISA.csv')

df_cs["DATE"] = pd.to_datetime(df_cs["DATE"])

mask = df_cs["DATE"] <= "2024-12-01"
df_cs = df_cs[mask]

df_cs.reset_index(inplace = True)
df_cs.drop(columns = ["index"], inplace = True)

df_cs["Year"] = pd.DatetimeIndex(df_cs["DATE"]).year
df_cs["Month"] = pd.DatetimeIndex(df_cs["DATE"]).month
print("Shape of the CASE_SHILLER Index:- ", df_cs.shape)
df_cs.tail()
# Out:
# Shape of the CASE_SHILLER Index:-  (240, 4)
#           DATE  CSUSHPISA  Year  Month
# 235 2023-08-01    308.830  2023      8
# 236 2023-09-01    310.894  2023      9
# 237 2023-10-01    312.756  2023     10
# 238 2023-11-01    313.632  2023     11
# 239 2023-12-01    314.443  2023     12

# %%
#unemployment rate
df_unemp = pd.read_csv("/content/UNRATE.csv")
df_unemp.drop([239], inplace = True)
print("Unemployment Rate Data:- ", df_unemp.shape)
df_unemp.tail()
# Out:
# Unemployment Rate Data:-  (239, 2)
#            DATE  UNRATE
# 234  2023-07-01     3.5
# 235  2023-08-01     3.8
# 236  2023-09-01     3.8
# 237  2023-10-01     3.8
# 238  2023-11-01     3.7

# %%
#employment rate
df_emp = pd.read_csv("/content/EmpRate.csv")
df_emp = df_emp.rename(columns={'LREM64TTUSM156S': 'EmpRate'})
df_emp.drop([239], inplace = True)
print("shape of the Employment Rate Data:- ", df_emp.shape)
df_emp.tail()
# Out:
# shape of the Employment Rate Data:-  (239, 2)
#            DATE   EmpRate
# 234  2023-07-01  71.96581
# 235  2023-08-01  72.06150
# 236  2023-09-01  72.05243
# 237  2023-10-01  71.97988
# 238  2023-11-01  72.09671

# %%
#per capita GDP
df_pcgdp = pd.read_csv("/content/PerCapita_GDP.csv", names = ["DATE", "A939RX0Q048SBEA"], skiprows = 1)
df_pcgdp = df_pcgdp.rename(columns={'A939RX0Q048SBEA': 'Per_Capita_GDP'})
print("Shape of the Per Capita GDP Data:- ", df_pcgdp.shape)
df_pcgdp.tail()
# Out:
# Shape of the Per Capita GDP Data:-  (19, 2)
#           DATE  Per_Capita_GDP
# 14  2018-01-01          38.859
# 15  2019-01-01          40.185
# 16  2020-01-01          44.147
# 17  2021-01-01          45.299
# 18  2022-01-01          48.021

# %%
#interest rates
df_Fed_rate = pd.read_csv("/content/FEDFUNDS.csv").drop([239])
print("Shape of the Interest rate data:- ",df_Fed_rate.shape)
df_Fed_rate.tail()
# Out:
# Shape of the Interest rate data:-  (239, 2)
#            DATE  FEDFUNDS
# 234  2023-07-01      5.12
# 235  2023-08-01      5.33
# 236  2023-09-01      5.33
# 237  2023-10-01      5.33
# 238  2023-11-01      5.33

# %%
#construction material
df_cons_price_index = pd.read_csv("/content/construction_material.csv", names = ["DATE", "WPUSI012011"], skiprows = 1)
df_cons_price_index = df_cons_price_index.rename(columns={'WPUSI012011': 'Cons_Material'})
df_cons_price_index.drop([239], inplace = True)
print("Shape of the Construction Material Data:- ", df_cons_price_index.shape)
df_cons_price_index.tail()
# Out:
# Shape of the Construction Material Data:-  (239, 2)
#            DATE  Cons_Material
# 234  2023-07-01        334.512
# 235  2023-08-01        333.794
# 236  2023-09-01        332.098
# 237  2023-10-01        328.743
# 238  2023-11-01        326.844

# %%
#consumer price
df_CPI = pd.read_csv("/content/CPI.csv", names = ["DATE", "CPIAUCSL"], skiprows = 1).drop([239])
df_CPI = df_CPI.rename(columns={'CPIAUCSL': 'CPI'})
print("Shape of the Consumer Price Index:- ", df_CPI.shape)
df_CPI.tail()
# Out:
# Shape of the Consumer Price Index:-  (239, 2)
#            DATE      CPI
# 234  2023-07-01  304.628
# 235  2023-08-01  306.187
# 236  2023-09-01  307.288
# 237  2023-10-01  307.531
# 238  2023-11-01  308.024

# %%
#monthly house supply
df_house = pd.read_csv("/content/monthly_house_supply.csv", names = ["DATE", "MSACSR"], skiprows = 1).drop([239])
df_house = df_house.rename(columns={'MSACSR': 'Houses'})
print("Shape of the monthly house supply data:- ", df_house.shape)
df_house.tail()
# Out:
# Shape of the monthly house supply data:-  (239, 2)
#            DATE  Houses
# 234  2023-07-01     7.3
# 235  2023-08-01     7.9
# 236  2023-09-01     7.5
# 237  2023-10-01     7.9
# 238  2023-11-01     8.8

# %%
#working age population
df_working = pd.read_csv("//content/working_age_pop.csv", names = ["DATE", "LFWA64TTUSM647S"], skiprows = 1).drop([114])
df_working = df_working.rename(columns={'LFWA64TTUSM647S': 'working_age_pop'})
print("Shape of the working age population:- ", df_working.shape)
df_working.tail()
# Out:
# Shape of the working age population:-  (114, 2)
#            DATE  working_age_pop
# 109  2023-07-01      208727000.0
# 110  2023-08-01      208810300.0
# 111  2023-09-01      208986900.0
# 112  2023-10-01      208948000.0
# 113  2023-11-01      209035600.0

# %%
#median household income
df_income = pd.read_csv("/content/median_income.csv", names = ["DATE", "MEHOINUSA672N"], skiprows = 1)
df_income = df_income.rename(columns={'MEHOINUSA672N': 'median_income'})
print("Shape of the median household income data:- ", df_income.shape)
df_income.tail()
# Out:
# Shape of the median household income data:-  (19, 2)
#           DATE  median_income
# 14  2018-01-01          73030
# 15  2019-01-01          78250
# 16  2020-01-01          76660
# 17  2021-01-01          76330
# 18  2022-01-01          74580

# %%
#total households
df_households = pd.read_csv("/content/num_of_households.csv", names = ["DATE", "TTLHH"], skiprows = 1)
df_households = df_households.rename(columns={'TTLHH': 'Num_Households'})
print("Shape of the total households data:- ", df_households.shape)
df_households.tail()
# Out:
# Shape of the total households data:-  (20, 2)
#           DATE  Num_Households
# 15  2019-01-01        128579.0
# 16  2020-01-01        128451.0
# 17  2021-01-01        129224.0
# 18  2022-01-01        131202.0
# 19  2023-01-01        131434.0

# %%
#merging per capita GDP Quarterly data
df_pcgdp["DATE"] = pd.to_datetime(df_pcgdp["DATE"])
df_cs = pd.merge(df_cs,df_pcgdp, how = "left")
df_cs.head()
# Out:
#         DATE  CSUSHPISA  Year  Month  Per_Capita_GDP
# 0 2004-01-01    141.647  2004      1          27.201
# 1 2004-02-01    143.192  2004      2             NaN
# 2 2004-03-01    145.058  2004      3             NaN
# 3 2004-04-01    146.592  2004      4             NaN
# 4 2004-05-01    148.186  2004      5             NaN

# %%
# merging dataframes having monthly data to create one dataframe
df = pd.DataFrame()
df_bymonth = [df_cs, df_working, df_house, df_CPI, df_unemp, df_emp, df_cons_price_index, df_Fed_rate]
for df1 in df_bymonth:
    df1["DATE"] = pd.to_datetime(df1["DATE"])
    df1 = df1.set_index("DATE")
    df = pd.concat([df,df1], axis = 1)
print(df.shape)
df.head()
# Out:
# (240, 11)
#             CSUSHPISA  Year  Month  Per_Capita_GDP  working_age_pop  Houses  \
# DATE
# 2004-01-01    141.647  2004      1          27.201              NaN     3.8
# 2004-02-01    143.192  2004      2             NaN              NaN     3.7
# 2004-03-01    145.058  2004      3             NaN              NaN     3.6
# 2004-04-01    146.592  2004      4             NaN              NaN     4.0
# 2004-05-01    148.186  2004      5             NaN              NaN     3.8
#
#               CPI  UNRATE   EmpRate  Cons_Material  FEDFUNDS
# DATE
# 2004-01-01  186.3     5.7  71.26121          150.0      1.00
# 2004-02-01  186.7     5.6  71.20414          153.4      1.01
# 2004-03-01  187.1     5.8  71.04634          156.5      1.00
# 2004-04-01  187.4     5.6  71.19504          160.1      1.00
# 2004-05-01  188.2     5.6  71.14265          162.7      1.00

# %%
# Merging other dataframes
others = [df_households, df_income]
for df1 in others:
    if "Year" not in df1.columns:
        df1["Year"] = pd.DatetimeIndex(df1["DATE"]).year
        df1.set_index("DATE", inplace = True)
        df = pd.merge(df, df1, how = "left", on = "Year")
    else:
        #df1.set_index("DATE", inplace = True)
        df = pd.merge(df, df1, how = "left", on = "Year")
df["DATE"] = df_cs["DATE"]
df.set_index("DATE", inplace = True)
df.head()
# Out:
#             CSUSHPISA  Year  Month  Per_Capita_GDP  working_age_pop  Houses  \
# DATE
# 2004-01-01    141.647  2004      1          27.201              NaN     3.8
# 2004-02-01    143.192  2004      2             NaN              NaN     3.7
# 2004-03-01    145.058  2004      3             NaN              NaN     3.6
# 2004-04-01    146.592  2004      4             NaN              NaN     4.0
# 2004-05-01    148.186  2004      5             NaN              NaN     3.8
#
#               CPI  UNRATE   EmpRate  Cons_Material  FEDFUNDS  Num_Households  \
# DATE
# 2004-01-01  186.3     5.7  71.26121          150.0      1.00        112000.0
# 2004-02-01  186.7     5.6  71.20414          153.4      1.01        112000.0
# 2004-03-01  187.1     5.8  71.04634          156.5      1.00        112000.0
# 2004-04-01  187.4     5.6  71.19504          160.1      1.00        112000.0
# 2004-05-01  188.2     5.6  71.14265          162.7      1.00        112000.0
#
#             median_income
# DATE
# 2004-01-01        65760.0
# 2004-02-01        65760.0
# 2004-03-01        65760.0
# 2004-04-01        65760.0
# 2004-05-01        65760.0

# %%
print(df.shape)
# Out:
# (240, 13)

# %% [markdown]
# CHECKING FOR MISSING VALUES

# %%
df.isna().sum()
# Out:
# CSUSHPISA            0
# Year                 0
# Month                0
# Per_Capita_GDP     221
# working_age_pop    126
# Houses               1
# CPI                  1
# UNRATE               1
# EmpRate              1
# Cons_Material        1
# FEDFUNDS             1
# Num_Households       0
# median_income       12
# dtype: int64

# %% [markdown]
# The "Per_Capita_GDP" column has missing values because the data was quarterly. The missing values in the other columns are due to the unavailability of fresh data. We will first fill in the missing values in the "Per_Capita_GDP" column using linear interpolation.

# %% [markdown]
# # **Interpolation**
# ---
# Interpolation is a mathematical technique used to estimate values that are missing in a dataset based on the values of neighboring data points. It calculates intermediate values based on the existing data.

# %%
# Filling missing values in the Per_Capita_GDP column using linear interpolation
df["Per_Capita_GDP"] = df["Per_Capita_GDP"].interpolate(meathod = 'linear')

# %%
df
# Out:
#             CSUSHPISA  Year  Month  Per_Capita_GDP  working_age_pop  Houses  \
# DATE
# 2004-01-01    141.647  2004      1         27.2010              NaN     3.8
# 2004-02-01    143.192  2004      2         27.2385              NaN     3.7
# 2004-03-01    145.058  2004      3         27.2760              NaN     3.6
# 2004-04-01    146.592  2004      4         27.3135              NaN     4.0
# 2004-05-01    148.186  2004      5         27.3510              NaN     3.8
# ...               ...   ...    ...             ...              ...     ...
# 2023-08-01    308.830  2023      8         48.0210      208810300.0     7.9
# 2023-09-01    310.894  2023      9         48.0210      208986900.0     7.5
# 2023-10-01    312.756  2023     10         48.0210      208948000.0     7.9
# 2023-11-01    313.632  2023     11         48.0210      209035600.0     8.8
# 2023-12-01    314.443  2023     12         48.0210              NaN     NaN
#
#                 CPI  UNRATE   EmpRate  Cons_Material  FEDFUNDS  \
# DATE
# 2004-01-01  186.300     5.7  71.26121        150.000      1.00
# 2004-02-01  186.700     5.6  71.20414        153.400      1.01
# 2004-03-01  187.100     5.8  71.04634        156.500      1.00
# 2004-04-01  187.400     5.6  71.19504        160.100      1.00
# 2004-05-01  188.200     5.6  71.14265        162.700      1.00
# ...             ...     ...       ...            ...       ...
# 2023-08-01  306.187     3.8  72.06150        333.794      5.33
# 2023-09-01  307.288     3.8  72.05243        332.098      5.33
# 2023-10-01  307.531     3.8  71.97988        328.743      5.33
# 2023-11-01  308.024     3.7  72.09671        326.844      5.33
# 2023-12-01      NaN     NaN       NaN            NaN       NaN
#
#             Num_Households  median_income
# DATE
# 2004-01-01        112000.0        65760.0
# 2004-02-01        112000.0        65760.0
# 2004-03-01        112000.0        65760.0
# 2004-04-01        112000.0        65760.0
# 2004-05-01        112000.0        65760.0
# ...                    ...            ...
# 2023-08-01        131434.0            NaN
# 2023-09-01        131434.0            NaN
# 2023-10-01        131434.0            NaN
# 2023-11-01        131434.0            NaN
# 2023-12-01        131434.0            NaN
#
# [240 rows x 13 columns]

# %%
df.isna().sum()
# Out:
# CSUSHPISA            0
# Year                 0
# Month                0
# Per_Capita_GDP       0
# working_age_pop    126
# Houses               1
# CPI                  1
# UNRATE               1
# EmpRate              1
# Cons_Material        1
# FEDFUNDS             1
# Num_Households       0
# median_income       12
# dtype: int64

# %%
print("shape of dataset: ", df.shape)
# Out:
# shape of dataset:  (240, 13)

# %% [markdown]
# #Saving Final Dataset

# %%
df.to_csv("saksham_UShomeprice_final_dataset.csv")

# %%
us_house_price_df = pd.read_csv("/content/saksham_UShomeprice_final_dataset.csv").set_index("DATE")
us_house_price_df.head()
# Out:
#             CSUSHPISA  Year  Month  Per_Capita_GDP  working_age_pop  Houses  \
# DATE
# 2004-01-01    141.647  2004      1         27.2010              NaN     3.8
# 2004-02-01    143.192  2004      2         27.2385              NaN     3.7
# 2004-03-01    145.058  2004      3         27.2760              NaN     3.6
# 2004-04-01    146.592  2004      4         27.3135              NaN     4.0
# 2004-05-01    148.186  2004      5         27.3510              NaN     3.8
#
#               CPI  UNRATE   EmpRate  Cons_Material  FEDFUNDS  Num_Households  \
# DATE
# 2004-01-01  186.3     5.7  71.26121          150.0      1.00        112000.0
# 2004-02-01  186.7     5.6  71.20414          153.4      1.01        112000.0
# 2004-03-01  187.1     5.8  71.04634          156.5      1.00        112000.0
# 2004-04-01  187.4     5.6  71.19504          160.1      1.00        112000.0
# 2004-05-01  188.2     5.6  71.14265          162.7      1.00        112000.0
#
#             median_income
# DATE
# 2004-01-01        65760.0
# 2004-02-01        65760.0
# 2004-03-01        65760.0
# 2004-04-01        65760.0
# 2004-05-01        65760.0

# %% [markdown]
# #DATA PREPARATION COMPLETE NOW DATA SCIENCE MODEL TO BE MADE AND DEPLOYED...
